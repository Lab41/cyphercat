# %% [markdown]
# # ML-Leaks Adversary 3

# %% [markdown]
# ## Imports

# %%
import sys 
import numpy as np 
import matplotlib.pyplot as plt


import torch
import torchvision 
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data.sampler import SubsetRandomSampler

sys.path.insert(0, '../src_code')

import models
from train import *
from metrics import * 

print("Python: %s" % sys.version)
print("Pytorch: %s" % torch.__version__)

# determine device to run network on (runs on gpu if available)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Python: 3.6.5 (default, Jun 21 2018, 23:07:39)
# [GCC 5.4.0 20160609]
# Pytorch: 0.4.0

# %% [markdown]
# ## Hyperparameters

# %%
n_epochs = 10
batch_size = 256
lr = 0.001

# %% [markdown]
# ## Load CIFAR10

# %%
# define series of transforms to pre process images 
transform = torchvision.transforms.Compose([
    # have to pad a few pixels for resnet
    torchvision.transforms.Pad(2),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]


# load training set 
cifar10_trainset = torchvision.datasets.CIFAR10('../datasets/', train=True, transform=transform, download=True)
cifar10_trainloader = torch.utils.data.DataLoader(cifar10_trainset, batch_size=batch_size, shuffle=True, num_workers=2)

# load test set 
cifar10_testset = torchvision.datasets.CIFAR10('../datasets/', train=False, transform=transform, download=True)
cifar10_testloader = torch.utils.data.DataLoader(cifar10_testset, batch_size=100, shuffle=False, num_workers=2)

# helper function to unnormalize and plot image 
def imshow(img):
    img = np.array(img)
    img = img / 2 + 0.5
    img = np.moveaxis(img, 0, -1)
    plt.imshow(img)
    
# display sample from dataset 
imgs,labels = iter(cifar10_trainloader).next()
imshow(torchvision.utils.make_grid(imgs))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## ML Leaks Adversary 3 (Membership Inference Attack)
# ### https://arxiv.org/abs/1806.01246

# %%
total_size = len(cifar10_trainset)


indices = list(range(total_size))

split = total_size // 2
target_train_idx = indices[:split]
target_out_idx = indices[split:]



target_train_sampler = SubsetRandomSampler(target_train_idx)
target_out_sampler = SubsetRandomSampler(target_out_idx)

target_train_loader = torch.utils.data.DataLoader(cifar10_trainset, batch_size=batch_size, sampler=target_train_sampler, num_workers=1)
target_out_loader = torch.utils.data.DataLoader(cifar10_trainset, batch_size=batch_size, sampler=target_out_sampler, num_workers=1)



# the model being attacked (architecture can be different than shadow)
target_net = torchvision.models.resnet18(num_classes=10).to(device)
target_net.avgpool = nn.AvgPool2d(2, stride=1)
#target_net = models.mlleaks_cnn().to(device)

target_net.apply(models.weights_init)

target_loss = nn.CrossEntropyLoss()
target_optim = optim.Adam(target_net.parameters(), lr=lr)

# %%
train(target_net, target_train_loader, cifar10_testloader, target_optim, target_loss, n_epochs, classes=classes)
# Out:
# [0/10]
# Accuracy of airplane : 71.80 %
# Accuracy of automobile : 64.30 %
# Accuracy of bird : 68.70 %
# Accuracy of cat : 9.90 %
# Accuracy of deer : 43.30 %
# Accuracy of dog : 41.20 %
# Accuracy of frog : 56.90 %
# Accuracy of horse : 64.50 %
# Accuracy of ship : 55.20 %
# Accuracy of truck : 61.40 %
#
# Total accuracy = 53.72 %
#
#
# [1/10]
# Accuracy of airplane : 53.60 %
# Accuracy of automobile : 83.60 %
# Accuracy of bird : 29.10 %
# Accuracy of cat : 19.20 %
# Accuracy of deer : 41.00 %
# Accuracy of dog : 63.20 %
# Accuracy of frog : 61.00 %
# Accuracy of horse : 49.00 %
# Accuracy of ship : 80.50 %
# Accuracy of truck : 67.60 %
#
# Total accuracy = 54.78 %
#
#
# [2/10]
# Accuracy of airplane : 76.20 %
# Accuracy of automobile : 72.80 %
# Accuracy of bird : 28.20 %
# Accuracy of cat : 44.10 %
# Accuracy of deer : 43.30 %
# Accuracy of dog : 65.30 %
# Accuracy of frog : 75.60 %
# Accuracy of horse : 77.90 %
# Accuracy of ship : 67.50 %
# Accuracy of truck : 71.50 %
#
# Total accuracy = 62.24 %
#
#
# [3/10]
# Accuracy of airplane : 76.30 %
# Accuracy of automobile : 67.30 %
# Accuracy of bird : 48.80 %
# Accuracy of cat : 48.40 %
# Accuracy of deer : 31.90 %
# Accuracy of dog : 60.40 %
# Accuracy of frog : 89.40 %
# Accuracy of horse : 61.10 %
# Accuracy of ship : 60.60 %
# Accuracy of truck : 77.10 %
#
# Total accuracy = 62.13 %
#
#
# [4/10]
# Accuracy of airplane : 71.70 %
# Accuracy of automobile : 78.40 %
# Accuracy of bird : 49.80 %
# Accuracy of cat : 26.30 %
# Accuracy of deer : 61.80 %
# Accuracy of dog : 49.50 %
# Accuracy of frog : 85.50 %
# Accuracy of horse : 61.70 %
# Accuracy of ship : 70.80 %
# Accuracy of truck : 82.10 %
#
# Total accuracy = 63.76 %
#
#
# [5/10]
# Accuracy of airplane : 70.70 %
# Accuracy of automobile : 78.90 %
# Accuracy of bird : 50.20 %
# Accuracy of cat : 53.10 %
# Accuracy of deer : 67.80 %
# Accuracy of dog : 49.70 %
# Accuracy of frog : 72.80 %
# Accuracy of horse : 75.20 %
# Accuracy of ship : 56.90 %
# Accuracy of truck : 71.30 %
#
# Total accuracy = 64.66 %
#
#
# [6/10]
# Accuracy of airplane : 78.30 %
# Accuracy of automobile : 84.30 %
# Accuracy of bird : 65.00 %
# Accuracy of cat : 38.10 %
# Accuracy of deer : 58.50 %
# Accuracy of dog : 60.10 %
# Accuracy of frog : 61.30 %
# Accuracy of horse : 79.10 %
# Accuracy of ship : 63.00 %
# Accuracy of truck : 57.90 %
#
# Total accuracy = 64.56 %
#
#
# [7/10]
# Accuracy of airplane : 65.00 %
# Accuracy of automobile : 68.00 %
# Accuracy of bird : 63.60 %
# Accuracy of cat : 30.70 %
# Accuracy of deer : 69.40 %
# Accuracy of dog : 66.20 %
# Accuracy of frog : 63.40 %
# Accuracy of horse : 74.40 %
# Accuracy of ship : 72.30 %
# Accuracy of truck : 82.60 %
#
# Total accuracy = 65.56 %
#
#
# [8/10]
# Accuracy of airplane : 73.00 %
# Accuracy of automobile : 78.90 %
# Accuracy of bird : 44.20 %
# Accuracy of cat : 63.30 %
# Accuracy of deer : 60.70 %
# Accuracy of dog : 56.80 %
# Accuracy of frog : 55.60 %
# Accuracy of horse : 64.20 %
# Accuracy of ship : 79.20 %
# Accuracy of truck : 73.90 %
#
# Total accuracy = 64.98 %
#
#
# [9/10]
# Accuracy of airplane : 68.70 %
# Accuracy of automobile : 84.10 %
# Accuracy of bird : 51.00 %
# Accuracy of cat : 37.50 %
# Accuracy of deer : 63.30 %
# Accuracy of dog : 63.10 %
# Accuracy of frog : 79.80 %
# Accuracy of horse : 77.40 %
# Accuracy of ship : 76.70 %
# Accuracy of truck : 66.70 %
#
# Total accuracy = 66.83 %

# %%
eval_membership_inference(target_net, target_train_loader, target_out_loader)
# Out:
# threshold = 0.5000, accuracy = 51.86, precision = 0.51, recall = 0.98
# threshold = 0.5050, accuracy = 51.99, precision = 0.51, recall = 0.98
# threshold = 0.5100, accuracy = 52.09, precision = 0.51, recall = 0.98
# threshold = 0.5150, accuracy = 52.19, precision = 0.51, recall = 0.98
# threshold = 0.5200, accuracy = 52.27, precision = 0.51, recall = 0.98
# threshold = 0.5250, accuracy = 52.33, precision = 0.51, recall = 0.98
# threshold = 0.5300, accuracy = 52.45, precision = 0.51, recall = 0.98
# threshold = 0.5350, accuracy = 52.53, precision = 0.51, recall = 0.97
# threshold = 0.5400, accuracy = 52.60, precision = 0.51, recall = 0.97
# threshold = 0.5450, accuracy = 52.67, precision = 0.51, recall = 0.97
# threshold = 0.5500, accuracy = 52.81, precision = 0.51, recall = 0.97
# threshold = 0.5550, accuracy = 52.87, precision = 0.52, recall = 0.97
# threshold = 0.5600, accuracy = 52.97, precision = 0.52, recall = 0.97
# threshold = 0.5650, accuracy = 53.08, precision = 0.52, recall = 0.96
# threshold = 0.5700, accuracy = 53.16, precision = 0.52, recall = 0.96
# threshold = 0.5750, accuracy = 53.26, precision = 0.52, recall = 0.96
# threshold = 0.5800, accuracy = 53.37, precision = 0.52, recall = 0.96
# threshold = 0.5850, accuracy = 53.47, precision = 0.52, recall = 0.96
# threshold = 0.5900, accuracy = 53.57, precision = 0.52, recall = 0.96
# threshold = 0.5950, accuracy = 53.66, precision = 0.52, recall = 0.96
# threshold = 0.6000, accuracy = 53.75, precision = 0.52, recall = 0.95
# threshold = 0.6050, accuracy = 53.86, precision = 0.52, recall = 0.95
# threshold = 0.6100, accuracy = 53.95, precision = 0.52, recall = 0.95
# threshold = 0.6150, accuracy = 54.00, precision = 0.52, recall = 0.95
# threshold = 0.6200, accuracy = 54.07, precision = 0.52, recall = 0.95
# threshold = 0.6250, accuracy = 54.16, precision = 0.52, recall = 0.95
# threshold = 0.6300, accuracy = 54.24, precision = 0.52, recall = 0.95
# threshold = 0.6350, accuracy = 54.33, precision = 0.52, recall = 0.94
# threshold = 0.6400, accuracy = 54.45, precision = 0.52, recall = 0.94
# threshold = 0.6450, accuracy = 54.57, precision = 0.53, recall = 0.94
# threshold = 0.6500, accuracy = 54.66, precision = 0.53, recall = 0.94
# threshold = 0.6550, accuracy = 54.77, precision = 0.53, recall = 0.94
# threshold = 0.6600, accuracy = 54.83, precision = 0.53, recall = 0.94
# threshold = 0.6650, accuracy = 54.95, precision = 0.53, recall = 0.94
# threshold = 0.6700, accuracy = 55.05, precision = 0.53, recall = 0.93
# threshold = 0.6750, accuracy = 55.12, precision = 0.53, recall = 0.93
# threshold = 0.6800, accuracy = 55.20, precision = 0.53, recall = 0.93
# threshold = 0.6850, accuracy = 55.25, precision = 0.53, recall = 0.93
# threshold = 0.6900, accuracy = 55.34, precision = 0.53, recall = 0.93
# threshold = 0.6950, accuracy = 55.38, precision = 0.53, recall = 0.92
# threshold = 0.7000, accuracy = 55.47, precision = 0.53, recall = 0.92
# threshold = 0.7050, accuracy = 55.56, precision = 0.53, recall = 0.92
# threshold = 0.7100, accuracy = 55.64, precision = 0.53, recall = 0.92
# threshold = 0.7150, accuracy = 55.73, precision = 0.53, recall = 0.92
# threshold = 0.7200, accuracy = 55.83, precision = 0.53, recall = 0.92
# threshold = 0.7250, accuracy = 55.95, precision = 0.53, recall = 0.91
# threshold = 0.7300, accuracy = 56.00, precision = 0.54, recall = 0.91
# threshold = 0.7350, accuracy = 56.09, precision = 0.54, recall = 0.91
# threshold = 0.7400, accuracy = 56.18, precision = 0.54, recall = 0.91
# threshold = 0.7450, accuracy = 56.27, precision = 0.54, recall = 0.91
# threshold = 0.7500, accuracy = 56.37, precision = 0.54, recall = 0.90
# threshold = 0.7550, accuracy = 56.45, precision = 0.54, recall = 0.90
# threshold = 0.7600, accuracy = 56.55, precision = 0.54, recall = 0.90
# threshold = 0.7650, accuracy = 56.64, precision = 0.54, recall = 0.90
# threshold = 0.7700, accuracy = 56.73, precision = 0.54, recall = 0.90
# threshold = 0.7750, accuracy = 56.76, precision = 0.54, recall = 0.89
# threshold = 0.7800, accuracy = 56.83, precision = 0.54, recall = 0.89
# threshold = 0.7850, accuracy = 56.92, precision = 0.54, recall = 0.89
# threshold = 0.7900, accuracy = 56.99, precision = 0.54, recall = 0.89
# threshold = 0.7950, accuracy = 57.09, precision = 0.54, recall = 0.88
# threshold = 0.8000, accuracy = 57.19, precision = 0.54, recall = 0.88
# threshold = 0.8050, accuracy = 57.24, precision = 0.54, recall = 0.88
# threshold = 0.8100, accuracy = 57.33, precision = 0.55, recall = 0.88
# threshold = 0.8150, accuracy = 57.48, precision = 0.55, recall = 0.88
# threshold = 0.8200, accuracy = 57.58, precision = 0.55, recall = 0.87
# threshold = 0.8250, accuracy = 57.67, precision = 0.55, recall = 0.87
# threshold = 0.8300, accuracy = 57.82, precision = 0.55, recall = 0.87
# threshold = 0.8350, accuracy = 57.91, precision = 0.55, recall = 0.86
# threshold = 0.8400, accuracy = 58.03, precision = 0.55, recall = 0.86
# threshold = 0.8450, accuracy = 58.10, precision = 0.55, recall = 0.86
# threshold = 0.8500, accuracy = 58.15, precision = 0.55, recall = 0.86
# threshold = 0.8550, accuracy = 58.23, precision = 0.55, recall = 0.85
# threshold = 0.8600, accuracy = 58.31, precision = 0.55, recall = 0.85
# threshold = 0.8650, accuracy = 58.41, precision = 0.56, recall = 0.85
# threshold = 0.8700, accuracy = 58.49, precision = 0.56, recall = 0.84
# threshold = 0.8750, accuracy = 58.59, precision = 0.56, recall = 0.84
# threshold = 0.8800, accuracy = 58.72, precision = 0.56, recall = 0.84
# threshold = 0.8850, accuracy = 58.82, precision = 0.56, recall = 0.83
# threshold = 0.8900, accuracy = 58.94, precision = 0.56, recall = 0.83
# threshold = 0.8950, accuracy = 59.00, precision = 0.56, recall = 0.82
# threshold = 0.9000, accuracy = 59.04, precision = 0.56, recall = 0.82
# threshold = 0.9050, accuracy = 59.19, precision = 0.56, recall = 0.81
# threshold = 0.9100, accuracy = 59.27, precision = 0.56, recall = 0.81
# threshold = 0.9150, accuracy = 59.39, precision = 0.57, recall = 0.80
# threshold = 0.9200, accuracy = 59.45, precision = 0.57, recall = 0.80
# threshold = 0.9250, accuracy = 59.48, precision = 0.57, recall = 0.79
# threshold = 0.9300, accuracy = 59.54, precision = 0.57, recall = 0.78
# threshold = 0.9350, accuracy = 59.62, precision = 0.57, recall = 0.78
# threshold = 0.9400, accuracy = 59.66, precision = 0.57, recall = 0.77
# threshold = 0.9450, accuracy = 59.74, precision = 0.57, recall = 0.76
# threshold = 0.9500, accuracy = 59.81, precision = 0.58, recall = 0.75
# threshold = 0.9550, accuracy = 59.87, precision = 0.58, recall = 0.74
# threshold = 0.9600, accuracy = 59.92, precision = 0.58, recall = 0.73
# threshold = 0.9650, accuracy = 59.86, precision = 0.58, recall = 0.72
# threshold = 0.9700, accuracy = 59.84, precision = 0.58, recall = 0.70
# threshold = 0.9750, accuracy = 59.78, precision = 0.58, recall = 0.68
# threshold = 0.9800, accuracy = 59.65, precision = 0.59, recall = 0.66
# threshold = 0.9850, accuracy = 59.36, precision = 0.59, recall = 0.63
# threshold = 0.9900, accuracy = 58.95, precision = 0.59, recall = 0.59
# threshold = 0.9950, accuracy = 58.05, precision = 0.59, recall = 0.52
